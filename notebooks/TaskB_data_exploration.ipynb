# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os

# %%
RESOURCES_DIR = Path("../resources")
TASK1_DIR = RESOURCES_DIR / "task_1"
TASK2_DIR = RESOURCES_DIR / "task_2"

# %%
# Step 1: Check if data files exist
rfq_path = TASK2_DIR / "rfq.csv"
reference_path = TASK2_DIR / "reference_properties.tsv"

print(f"Checking for data files...")
print(f"Looking in: {TASK2_DIR}")
print(f"rfq.csv exists: {rfq_path.exists()}")
print(f"reference_properties.tsv exists: {reference_path.exists()}")
# Out:
# Checking for data files...
# Looking in: ../resources/task_2
# rfq.csv exists: True
# reference_properties.tsv exists: True

# %%
# Step 2: Load and examine rfq.csv

rfq_df = pd.read_csv(rfq_path)
pd.set_option("display.max_columns", None)  # show all columns
pd.set_option("display.width", None)       # don't wrap columns
rfq_df.head()
# Out:
#                                      id   grade  grade_suffix coating  \
# 0  8aff426d-b8c0-43aa-ad26-835ef4de6129  S700MC           NaN     NaN
# 1  37e624be-b125-464f-85b6-1838530193ef  S250GD           NaN   ZM310
# 2  b8257184-6307-46ab-b06e-d979336d1263   DX51D           NaN    Z100
# 3  63140d1f-dda8-40fe-8931-bcaba65d5772    S235           NaN     NaN
# 4  11cffc57-44be-4d79-bfd5-97482be566d3    S235           NaN     NaN
#
#                          finish surface_type surface_protection         form  \
# 0                         Oiled          NaN                NaN        Coils
# 1  Hot-dip zinc magnesium (+ZM)          NaN                NaN   Slit Coils
# 2   Hot-dip Galvanized (+Z/+GI)          NaN  Lightly Oiled (L)        Coils
# 3                           NaN          NaN                NaN  Round Tubes
# 4                           NaN          NaN                NaN  Round Tubes
#
#    thickness_min  thickness_max  width_min  width_max  length_min  height_min  \
# 0            6.0            6.0      600.0     1520.0         NaN         NaN
# 1            1.5            1.5      327.0      327.0         NaN         NaN
# 2            0.4            0.4     1000.0     1500.0         NaN         NaN
# 3            1.5            1.5        NaN        NaN      4900.0      4900.0
# 4            1.5            1.5        NaN        NaN      6100.0      6100.0
#
#    height_max  weight_min  weight_max  inner_diameter_min  inner_diameter_max  \
# 0         NaN     15000.0     25000.0               610.0               610.0
# 1         NaN         NaN         NaN                 NaN                 NaN
# 2         NaN         NaN         NaN                 NaN                 NaN
# 3         NaN     53800.0     53800.0                 NaN                 NaN
# 4         NaN     14500.0     14500.0                 NaN                 NaN
#
#    outer_diameter_min  outer_diameter_max  yield_strength_min  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                60.3                 NaN                 NaN
# 4                48.3                 NaN                 NaN
#
#    yield_strength_max  tensile_strength_min  tensile_strength_max
# 0                 NaN                 760.0                 810.0
# 1                 NaN                   NaN                   NaN
# 2                 NaN                   NaN                   NaN
# 3                 NaN                   NaN                   NaN
# 4                 NaN                   NaN                   NaN

# %%
print(f"Shape: {rfq_df.shape}")
# Out:
# Shape: (1000, 25)

# %%
print(f"\nData types:")
print(rfq_df.dtypes)
# Out:
# Data types:
# id                       object
# grade                    object
# grade_suffix            float64
# coating                  object
# finish                   object
# surface_type             object
# surface_protection       object
# form                     object
# thickness_min           float64
# thickness_max           float64
# width_min               float64
# width_max               float64
# length_min              float64
# height_min              float64
# height_max              float64
# weight_min              float64
# weight_max              float64
# inner_diameter_min      float64
# inner_diameter_max      float64
# outer_diameter_min      float64
# outer_diameter_max      float64
# yield_strength_min      float64
# yield_strength_max      float64
# tensile_strength_min    float64
# tensile_strength_max    float64
# dtype: object

# %%
print(f"\nMissing values:")
print(rfq_df.isnull().sum())
# Out:
# Missing values:
# id                         0
# grade                     59
# grade_suffix            1000
# coating                  682
# finish                   335
# surface_type             865
# surface_protection       713
# form                      73
# thickness_min            167
# thickness_max            166
# width_min                461
# width_max                348
# length_min               869
# height_min               868
# height_max               998
# weight_min               607
# weight_max               369
# inner_diameter_min       823
# inner_diameter_max       822
# outer_diameter_min       977
# outer_diameter_max       980
# yield_strength_min       964
# yield_strength_max       984
# tensile_strength_min     951
# tensile_strength_max     949
# dtype: int64

# %%
print("\nBasic statistics:")
print(rfq_df.describe(include='all'))
# Out:
# Basic statistics:
#                                           id  grade  grade_suffix coating  \
# count                                   1000    941           0.0     318
# unique                                  1000    158           NaN      62
# top     8aff426d-b8c0-43aa-ad26-835ef4de6129  DX51D           NaN    Z275
# freq                                       1     95           NaN      40
# mean                                     NaN    NaN           NaN     NaN
# std                                      NaN    NaN           NaN     NaN
# min                                      NaN    NaN           NaN     NaN
# 25%                                      NaN    NaN           NaN     NaN
# 50%                                      NaN    NaN           NaN     NaN
# 75%                                      NaN    NaN           NaN     NaN
# max                                      NaN    NaN           NaN     NaN
#
#                              finish  \
# count                           665
# unique                           47
# top     Hot-dip Galvanized (+Z/+GI)
# freq                            144
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN
#
#                                         surface_type surface_protection  \
# count                                            135                287
# unique                                            14                 15
# top     Minimized spangle, conventional surface (MA)          Oiled (O)
# freq                                              39                121
# mean                                             NaN                NaN
# std                                              NaN                NaN
# min                                              NaN                NaN
# 25%                                              NaN                NaN
# 50%                                              NaN                NaN
# 75%                                              NaN                NaN
# max                                              NaN                NaN
#
#          form  thickness_min  thickness_max    width_min    width_max  \
# count     927     833.000000      834.00000   539.000000   652.000000
# unique     17            NaN            NaN          NaN          NaN
# top     Coils            NaN            NaN          NaN          NaN
# freq      615            NaN            NaN          NaN          NaN
# mean      NaN       5.752977        5.96693   963.207421  1276.799080
# std       NaN      15.100137       15.10109   614.141337   774.410463
# min       NaN       0.010000        0.11000     2.900000     3.000000
# 25%       NaN       1.200000        1.30000   600.000000  1103.750000
# 50%       NaN       2.000000        2.00000  1000.000000  1500.000000
# 75%       NaN       4.000000        4.00000  1500.000000  1520.000000
# max       NaN     190.000000      190.00000  3700.000000  8000.000000
#
#            length_min     height_min  height_max    weight_min    weight_max  \
# count      131.000000     132.000000         2.0  3.930000e+02  6.310000e+02
# unique            NaN            NaN         NaN           NaN           NaN
# top               NaN            NaN         NaN           NaN           NaN
# freq              NaN            NaN         NaN           NaN           NaN
# mean      5176.641221    5278.901515        80.0  1.130755e+05  8.344872e+04
# std       9920.773435   10405.449859         0.0  1.264805e+06  9.986408e+05
# min         50.000000     100.000000        80.0  2.000000e+01  1.000000e+03
# 25%       3000.000000    3000.000000        80.0  1.000000e+04  2.050000e+04
# 50%       3000.000000    3000.000000        80.0  2.000000e+04  2.500000e+04
# 75%       6000.000000    6000.000000        80.0  4.000000e+04  2.500000e+04
# max     114000.000000  120000.000000        80.0  2.500000e+07  2.500000e+07
#
#         inner_diameter_min  inner_diameter_max  outer_diameter_min  \
# count           177.000000          178.000000           23.000000
# unique                 NaN                 NaN                 NaN
# top                    NaN                 NaN                 NaN
# freq                   NaN                 NaN                 NaN
# mean            607.559322          609.820225          769.104348
# std              31.193096           14.900470         1389.261845
# min             260.000000          508.000000           20.000000
# 25%             610.000000          610.000000          401.850000
# 50%             610.000000          610.000000          610.000000
# 75%             610.000000          610.000000          610.000000
# max             760.000000          760.000000         7016.000000
#
#         outer_diameter_max  yield_strength_min  yield_strength_max  \
# count            20.000000           36.000000           16.000000
# unique                 NaN                 NaN                 NaN
# top                    NaN                 NaN                 NaN
# freq                   NaN                 NaN                 NaN
# mean           1036.985000          308.194444          327.500000
# std            1453.795719           87.130057           36.055513
# min             193.700000          220.000000          280.000000
# 25%             610.000000          260.000000          300.000000
# 50%             610.000000          260.000000          330.000000
# 75%             610.000000          355.000000          350.000000
# max            7016.000000          700.000000          380.000000
#
#         tensile_strength_min  tensile_strength_max
# count              49.000000             51.000000
# unique                   NaN                   NaN
# top                      NaN                   NaN
# freq                     NaN                   NaN
# mean              440.256122            550.150000
# std               135.127971            158.594822
# min                 2.550000              2.650000
# 25%               350.000000            420.000000
# 50%               450.000000            560.000000
# 75%               540.000000            640.000000
# max               760.000000            965.000000

# %%
print("Unique values per column:")
for col in rfq_df.columns:
    uniques = rfq_df[col].unique()[:5]  # first 5 unique values
    print(f"{col}: {rfq_df[col].nunique()} unique values")
    print(f"  First 5 unique values: {list(uniques)}")
# Out:
# Unique values per column:
# id: 1000 unique values
#   First 5 unique values: ['8aff426d-b8c0-43aa-ad26-835ef4de6129', '37e624be-b125-464f-85b6-1838530193ef', 'b8257184-6307-46ab-b06e-d979336d1263', '63140d1f-dda8-40fe-8931-bcaba65d5772', '11cffc57-44be-4d79-bfd5-97482be566d3']
# grade: 158 unique values
#   First 5 unique values: ['S700MC', 'S250GD', 'DX51D', 'S235', 'S355MC']
# grade_suffix: 0 unique values
#   First 5 unique values: [np.float64(nan)]
# coating: 62 unique values
#   First 5 unique values: [nan, 'ZM310', 'Z100', 'Z075', 'Z080']
# finish: 47 unique values
#   First 5 unique values: ['Oiled', 'Hot-dip zinc magnesium (+ZM)', 'Hot-dip Galvanized (+Z/+GI)', nan, 'Galvanized']
# surface_type: 14 unique values
#   First 5 unique values: [nan, 'Conventional surface (A)', 'Minimized spangle, improved surface (MB)', 'Minimized spangle, conventional surface (MA)', 'Non-specified']
# surface_protection: 15 unique values
#   First 5 unique values: [nan, 'Lightly Oiled (L)', 'Oiled (O)', 'Phosphated, chemically passivated and oiled (PCO)', 'Phosphated and chemically passivated (PC)']
# form: 17 unique values
#   First 5 unique values: ['Coils', 'Slit Coils', 'Round Tubes', 'Rectangular Tubes', 'Equal Angles']
# thickness_min: 144 unique values
#   First 5 unique values: [np.float64(6.0), np.float64(1.5), np.float64(0.4), np.float64(2.0), np.float64(2.5)]
# thickness_max: 134 unique values
#   First 5 unique values: [np.float64(6.0), np.float64(1.5), np.float64(0.4), np.float64(2.0), np.float64(2.5)]
# width_min: 138 unique values
#   First 5 unique values: [np.float64(600.0), np.float64(327.0), np.float64(1000.0), np.float64(nan), np.float64(60.0)]
# width_max: 111 unique values
#   First 5 unique values: [np.float64(1520.0), np.float64(327.0), np.float64(1500.0), np.float64(nan), np.float64(60.0)]
# length_min: 33 unique values
#   First 5 unique values: [np.float64(nan), np.float64(4900.0), np.float64(6100.0), np.float64(6200.0), np.float64(9000.0)]
# height_min: 31 unique values
#   First 5 unique values: [np.float64(nan), np.float64(4900.0), np.float64(6100.0), np.float64(6200.0), np.float64(9000.0)]
# height_max: 1 unique values
#   First 5 unique values: [np.float64(nan), np.float64(80.0)]
# weight_min: 54 unique values
#   First 5 unique values: [np.float64(15000.0), np.float64(nan), np.float64(53800.0), np.float64(14500.0), np.float64(34000.0)]
# weight_max: 57 unique values
#   First 5 unique values: [np.float64(25000.0), np.float64(nan), np.float64(53800.0), np.float64(14500.0), np.float64(34000.0)]
# inner_diameter_min: 5 unique values
#   First 5 unique values: [np.float64(610.0), np.float64(nan), np.float64(760.0), np.float64(480.0), np.float64(508.0)]
# inner_diameter_max: 4 unique values
#   First 5 unique values: [np.float64(610.0), np.float64(nan), np.float64(760.0), np.float64(530.0), np.float64(508.0)]
# outer_diameter_min: 9 unique values
#   First 5 unique values: [np.float64(nan), np.float64(60.3), np.float64(48.3), np.float64(20.0), np.float64(25.0)]
# outer_diameter_max: 6 unique values
#   First 5 unique values: [np.float64(nan), np.float64(193.7), np.float64(610.0), np.float64(7016.0), np.float64(1980.0)]
# yield_strength_min: 9 unique values
#   First 5 unique values: [np.float64(nan), np.float64(235.0), np.float64(355.0), np.float64(260.0), np.float64(380.0)]
# yield_strength_max: 5 unique values
#   First 5 unique values: [np.float64(nan), np.float64(280.0), np.float64(300.0), np.float64(380.0), np.float64(340.0)]
# tensile_strength_min: 16 unique values
#   First 5 unique values: [np.float64(760.0), np.float64(nan), np.float64(300.0), np.float64(570.0), np.float64(470.0)]
# tensile_strength_max: 16 unique values
#   First 5 unique values: [np.float64(810.0), np.float64(nan), np.float64(360.0), np.float64(710.0), np.float64(630.0)]

# %%
# Step 3: Load and examine supplier_data2.xlsx
reference_df = pd.read_csv(reference_path, sep='\t')
reference_df.head()
# Out:
#   Grade/Material  UNS_No  Steel_No        Standards Carbon (C) Manganese (Mn)  \
# 0         S235JR     NaN       NaN  EN 10025-2:2019      ≤0.17          ≤1.40
# 1         S275JR     NaN       NaN  EN 10025-2:2019      ≤0.21          ≤1.50
# 2         S355JR     NaN       NaN  EN 10025-2:2019      ≤0.24          ≤1.60
# 3          S420M     NaN       NaN  EN 10025-3:2019      ≤0.20      1.00-1.70
# 4          S460M     NaN       NaN  EN 10025-3:2019      ≤0.20      1.00-1.70
#
#   Silicon (Si) Sulfur (S) Phosphorus (P) Chromium (Cr) Nickel (Ni)  \
# 0        ≤0.40     ≤0.035         ≤0.035           NaN         NaN
# 1        ≤0.40     ≤0.035         ≤0.035           NaN         NaN
# 2        ≤0.55     ≤0.035         ≤0.035           NaN         NaN
# 3        ≤0.50     ≤0.025         ≤0.030         ≤0.30       ≤0.50
# 4        ≤0.50     ≤0.025         ≤0.030         ≤0.30       ≤0.50
#
#   Molybdenum (Mo) Vanadium (V)  Tungsten (W)  Cobalt (Co) Copper (Cu)  \
# 0             NaN          NaN           NaN          NaN         NaN
# 1             NaN          NaN           NaN          NaN         NaN
# 2             NaN          NaN           NaN          NaN         NaN
# 3           ≤0.10          NaN           NaN          NaN         NaN
# 4           ≤0.10          NaN           NaN          NaN         NaN
#
#   Aluminum (Al) Titanium (Ti) Niobium (Nb) Boron (B) Nitrogen (N)  \
# 0           NaN           NaN          NaN       NaN       ≤0.012
# 1           NaN           NaN          NaN       NaN       ≤0.012
# 2           NaN           NaN          NaN       NaN       ≤0.012
# 3           NaN           NaN          NaN       NaN       ≤0.015
# 4           NaN           NaN          NaN       NaN       ≤0.015
#
#   Tensile strength (Rm) Yield strength (Re or Rp0.2) Elongation (A%)  \
# 0           360-510 MPa                     ≥235 MPa            ≥26%
# 1           410-560 MPa                     ≥275 MPa            ≥23%
# 2           470-630 MPa                     ≥355 MPa            ≥22%
# 3           520-680 MPa                     ≥420 MPa            ≥19%
# 4           540-720 MPa                     ≥460 MPa            ≥17%
#
#    Reduction of area (Z%) Hardness (HB, HV, HRC)  \
# 0                     NaN                    NaN
# 1                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN                    NaN
# 4                     NaN                    NaN
#
#   Impact toughness (Charpy V-notch)  Fatigue limit  Creep resistance  \
# 0                       27J at 20°C            NaN               NaN
# 1                       27J at 20°C            NaN               NaN
# 2                       27J at 20°C            NaN               NaN
# 3                      27J at -20°C            NaN               NaN
# 4                      27J at -20°C            NaN               NaN
#
#               Source_Pages                       Application  \
# 0  Standard Specifications         General structural steels
# 1  Standard Specifications         General structural steels
# 2  Standard Specifications         General structural steels
# 3  Standard Specifications  Thermomechanically rolled steels
# 4  Standard Specifications  Thermomechanically rolled steels
#
#               Category Nb + V + Ti (Others) Coating
# 0     Structural Steel                  NaN     NaN
# 1     Structural Steel                  NaN     NaN
# 2     Structural Steel                  NaN     NaN
# 3  High Strength Steel                  NaN     NaN
# 4  High Strength Steel                  NaN     NaN

# %%
print(f"Shape: {reference_df.shape}")
# Out:
# Shape: (175, 34)

# %%
print(f"\nData types:")
print(reference_df.dtypes)
# Out:
# Data types:
# Grade/Material                        object
# UNS_No                               float64
# Steel_No                             float64
# Standards                             object
# Carbon (C)                            object
# Manganese (Mn)                        object
# Silicon (Si)                          object
# Sulfur (S)                            object
# Phosphorus (P)                        object
# Chromium (Cr)                         object
# Nickel (Ni)                           object
# Molybdenum (Mo)                       object
# Vanadium (V)                          object
# Tungsten (W)                         float64
# Cobalt (Co)                          float64
# Copper (Cu)                           object
# Aluminum (Al)                         object
# Titanium (Ti)                         object
# Niobium (Nb)                          object
# Boron (B)                             object
# Nitrogen (N)                          object
# Tensile strength (Rm)                 object
# Yield strength (Re or Rp0.2)          object
# Elongation (A%)                       object
# Reduction of area (Z%)               float64
# Hardness (HB, HV, HRC)                object
# Impact toughness (Charpy V-notch)     object
# Fatigue limit                        float64
# Creep resistance                     float64
# Source_Pages                          object
# Application                           object
# Category                              object
# Nb + V + Ti (Others)                  object
# Coating                               object
# dtype: object

# %%
print(f"\nMissing values:")
print(reference_df.isnull().sum())
# Out:
# Missing values:
# Grade/Material                         0
# UNS_No                               175
# Steel_No                             175
# Standards                              0
# Carbon (C)                             0
# Manganese (Mn)                         0
# Silicon (Si)                          41
# Sulfur (S)                            12
# Phosphorus (P)                        12
# Chromium (Cr)                        133
# Nickel (Ni)                          159
# Molybdenum (Mo)                      145
# Vanadium (V)                         150
# Tungsten (W)                         175
# Cobalt (Co)                          175
# Copper (Cu)                          174
# Aluminum (Al)                         81
# Titanium (Ti)                        146
# Niobium (Nb)                         149
# Boron (B)                            167
# Nitrogen (N)                         158
# Tensile strength (Rm)                  0
# Yield strength (Re or Rp0.2)          11
# Elongation (A%)                       21
# Reduction of area (Z%)               175
# Hardness (HB, HV, HRC)               142
# Impact toughness (Charpy V-notch)    159
# Fatigue limit                        175
# Creep resistance                     175
# Source_Pages                           0
# Application                            0
# Category                               0
# Nb + V + Ti (Others)                 167
# Coating                              155
# dtype: int64

# %%
print("\nBasic statistics:")
print(reference_df.describe(include='all'))
# Out:
# Basic statistics:
#        Grade/Material  UNS_No  Steel_No                 Standards Carbon (C)  \
# count             175     0.0       0.0                       175        175
# unique            175     NaN       NaN                        25         53
# top            S235JR     NaN       NaN  Automotive specification      ≤0.12
# freq                1     NaN       NaN                        67         52
# mean              NaN     NaN       NaN                       NaN        NaN
# std               NaN     NaN       NaN                       NaN        NaN
# min               NaN     NaN       NaN                       NaN        NaN
# 25%               NaN     NaN       NaN                       NaN        NaN
# 50%               NaN     NaN       NaN                       NaN        NaN
# 75%               NaN     NaN       NaN                       NaN        NaN
# max               NaN     NaN       NaN                       NaN        NaN
#
#        Manganese (Mn) Silicon (Si) Sulfur (S) Phosphorus (P) Chromium (Cr)  \
# count             175          134        163            163            42
# unique             50           19          9             12            23
# top             ≤1.60        ≤0.50     ≤0.015         ≤0.025         ≤0.30
# freq               18           52         71             69             7
# mean              NaN          NaN        NaN            NaN           NaN
# std               NaN          NaN        NaN            NaN           NaN
# min               NaN          NaN        NaN            NaN           NaN
# 25%               NaN          NaN        NaN            NaN           NaN
# 50%               NaN          NaN        NaN            NaN           NaN
# 75%               NaN          NaN        NaN            NaN           NaN
# max               NaN          NaN        NaN            NaN           NaN
#
#        Nickel (Ni) Molybdenum (Mo) Vanadium (V)  Tungsten (W)  Cobalt (Co)  \
# count           16              30           25           0.0          0.0
# unique          13              14            5           NaN          NaN
# top          ≤0.50       0.15-0.30        ≤0.20           NaN          NaN
# freq             4               6           21           NaN          NaN
# mean           NaN             NaN          NaN           NaN          NaN
# std            NaN             NaN          NaN           NaN          NaN
# min            NaN             NaN          NaN           NaN          NaN
# 25%            NaN             NaN          NaN           NaN          NaN
# 50%            NaN             NaN          NaN           NaN          NaN
# 75%            NaN             NaN          NaN           NaN          NaN
# max            NaN             NaN          NaN           NaN          NaN
#
#        Copper (Cu) Aluminum (Al) Titanium (Ti) Niobium (Nb) Boron (B)  \
# count            1            94            29           26         8
# unique           1             7             4            4         2
# top        3.0-5.0   0.015-0.070         ≤0.15        ≤0.09    ≤0.005
# freq             1            35            23           23         4
# mean           NaN           NaN           NaN          NaN       NaN
# std            NaN           NaN           NaN          NaN       NaN
# min            NaN           NaN           NaN          NaN       NaN
# 25%            NaN           NaN           NaN          NaN       NaN
# 50%            NaN           NaN           NaN          NaN       NaN
# 75%            NaN           NaN           NaN          NaN       NaN
# max            NaN           NaN           NaN          NaN       NaN
#
#        Nitrogen (N) Tensile strength (Rm) Yield strength (Re or Rp0.2)  \
# count            17                   175                          164
# unique            5                    75                           55
# top          ≤0.012           470-630 MPa                     ≥355 MPa
# freq             10                    13                           13
# mean            NaN                   NaN                          NaN
# std             NaN                   NaN                          NaN
# min             NaN                   NaN                          NaN
# 25%             NaN                   NaN                          NaN
# 50%             NaN                   NaN                          NaN
# 75%             NaN                   NaN                          NaN
# max             NaN                   NaN                          NaN
#
#        Elongation (A%)  Reduction of area (Z%) Hardness (HB, HV, HRC)  \
# count              154                     0.0                     33
# unique              31                     NaN                     22
# top               ≥22%                     NaN                ≤200 HB
# freq                16                     NaN                      4
# mean               NaN                     NaN                    NaN
# std                NaN                     NaN                    NaN
# min                NaN                     NaN                    NaN
# 25%                NaN                     NaN                    NaN
# 50%                NaN                     NaN                    NaN
# 75%                NaN                     NaN                    NaN
# max                NaN                     NaN                    NaN
#
#        Impact toughness (Charpy V-notch)  Fatigue limit  Creep resistance  \
# count                                 16            0.0               0.0
# unique                                 5            NaN               NaN
# top                         27J at -20°C            NaN               NaN
# freq                                   5            NaN               NaN
# mean                                 NaN            NaN               NaN
# std                                  NaN            NaN               NaN
# min                                  NaN            NaN               NaN
# 25%                                  NaN            NaN               NaN
# 50%                                  NaN            NaN               NaN
# 75%                                  NaN            NaN               NaN
# max                                  NaN            NaN               NaN
#
#                    Source_Pages                      Application    Category  \
# count                       175                              175         175
# unique                        1                              102          25
# top     Standard Specifications  Cold forming microalloyed steel  HSLA Steel
# freq                        175                               10          34
# mean                        NaN                              NaN         NaN
# std                         NaN                              NaN         NaN
# min                         NaN                              NaN         NaN
# 25%                         NaN                              NaN         NaN
# 50%                         NaN                              NaN         NaN
# 75%                         NaN                              NaN         NaN
# max                         NaN                              NaN         NaN
#
#        Nb + V + Ti (Others)             Coating
# count                     8                  20
# unique                    1                   1
# top                   ≤0.22  Hot-dip galvanized
# freq                      8                  20
# mean                    NaN                 NaN
# std                     NaN                 NaN
# min                     NaN                 NaN
# 25%                     NaN                 NaN
# 50%                     NaN                 NaN
# 75%                     NaN                 NaN
# max                     NaN                 NaN

# %%
print("Unique values per column:")
for col in reference_df.columns:
    uniques = reference_df[col].unique()[:5]  # first 5 unique values
    print(f"{col}: {reference_df[col].nunique()} unique values")
    print(f"  First 5 unique values: {list(uniques)}")
# Out:
# Unique values per column:
# Grade/Material: 175 unique values
#   First 5 unique values: ['S235JR', 'S275JR', 'S355JR', 'S420M', 'S460M']
# UNS_No: 0 unique values
#   First 5 unique values: [np.float64(nan)]
# Steel_No: 0 unique values
#   First 5 unique values: [np.float64(nan)]
# Standards: 25 unique values
#   First 5 unique values: ['EN 10025-2:2019', 'EN 10025-3:2019', 'EN 10149-2:2013', 'EN 10130:2006', 'EN 10111:2008']
# Carbon (C): 53 unique values
#   First 5 unique values: ['≤0.17', '≤0.21', '≤0.24', '≤0.20', '≤0.12']
# Manganese (Mn): 50 unique values
#   First 5 unique values: ['≤1.40', '≤1.50', '≤1.60', '1.00-1.70', '≤1.70']
# Silicon (Si): 19 unique values
#   First 5 unique values: ['≤0.40', '≤0.55', '≤0.50', '≤0.60', nan]
# Sulfur (S): 9 unique values
#   First 5 unique values: ['≤0.035', '≤0.025', '≤0.015', '≤0.045', '≤0.030']
# Phosphorus (P): 12 unique values
#   First 5 unique values: ['≤0.035', '≤0.030', '≤0.025', '≤0.045', '≤0.120']
# Chromium (Cr): 23 unique values
#   First 5 unique values: [nan, '≤0.30', '≤0.50', '≤0.40', '≤0.60']
# Nickel (Ni): 13 unique values
#   First 5 unique values: [nan, '≤0.50', '≤1.00', '≤1.50', '≤2.50']
# Molybdenum (Mo): 14 unique values
#   First 5 unique values: [nan, '≤0.10', '≤0.30', '≤0.20', '≤0.25']
# Vanadium (V): 5 unique values
#   First 5 unique values: [nan, '≤0.20', '0.70-1.20', '≤0.30', '0.80-1.20']
# Tungsten (W): 0 unique values
#   First 5 unique values: [np.float64(nan)]
# Cobalt (Co): 0 unique values
#   First 5 unique values: [np.float64(nan)]
# Copper (Cu): 1 unique values
#   First 5 unique values: [nan, '3.0-5.0']
# Aluminum (Al): 7 unique values
#   First 5 unique values: [nan, '≥0.015', '≥0.010', '0.020-0.070', '0.015-0.070']
# Titanium (Ti): 4 unique values
#   First 5 unique values: [nan, '≤0.15', '0.010-0.050', '5×C-0.70', '0.020-0.050']
# Niobium (Nb): 4 unique values
#   First 5 unique values: [nan, '≤0.09', '0.015-0.050', '0.15-0.45', '≤0.05']
# Boron (B): 2 unique values
#   First 5 unique values: [nan, '≤0.005', '0.0008-0.0050']
# Nitrogen (N): 5 unique values
#   First 5 unique values: ['≤0.012', '≤0.015', nan, '≤0.10', '≤0.11']
# Tensile strength (Rm): 75 unique values
#   First 5 unique values: ['360-510 MPa', '410-560 MPa', '470-630 MPa', '520-680 MPa', '540-720 MPa']
# Yield strength (Re or Rp0.2): 55 unique values
#   First 5 unique values: ['≥235 MPa', '≥275 MPa', '≥355 MPa', '≥420 MPa', '≥460 MPa']
# Elongation (A%): 31 unique values
#   First 5 unique values: ['≥26%', '≥23%', '≥22%', '≥19%', '≥17%']
# Reduction of area (Z%): 0 unique values
#   First 5 unique values: [np.float64(nan)]
# Hardness (HB, HV, HRC): 22 unique values
#   First 5 unique values: [nan, '370-430 HB', '470-530 HB', '60-62 HRC', '54-58 HRC']
# Impact toughness (Charpy V-notch): 5 unique values
#   First 5 unique values: ['27J at 20°C', '27J at -20°C', nan, '≥35J at -20°C', '≥27J at 20°C']
# Fatigue limit: 0 unique values
#   First 5 unique values: [np.float64(nan)]
# Creep resistance: 0 unique values
#   First 5 unique values: [np.float64(nan)]
# Source_Pages: 1 unique values
#   First 5 unique values: ['Standard Specifications']
# Application: 102 unique values
#   First 5 unique values: ['General structural steels', 'Thermomechanically rolled steels', 'Cold forming, automotive', 'Cold forming, automotive, high strength applications', 'Ultra high strength applications, automotive']
# Category: 25 unique values
#   First 5 unique values: ['Structural Steel', 'High Strength Steel', 'Microalloyed Steel', 'Ultra High Strength Steel', 'Cold Rolled Steel']
# Nb + V + Ti (Others): 1 unique values
#   First 5 unique values: [nan, '≤0.22']
# Coating: 1 unique values
#   First 5 unique values: [nan, 'Hot-dip galvanized']
